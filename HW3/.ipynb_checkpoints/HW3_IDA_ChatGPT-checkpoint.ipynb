# %% [markdown]
# ### Use ChatGPT and IDA Model to find the topic in recent Canada Education news
# * Search education news on CBC(Canadian Broadcasting Corporation) News
# * Store news report contents in txt files respectively
# * Use the codes below to analyze the most popular 3 topic
# * Data Date : 2023/4/12
#
# [CBC: Search for Education](https://www.cbc.ca/search?q=education&section=news&sortOrder=relevance&media=all)
# [IDA Model introduction](https://blog.csdn.net/qq_39496504/article/details/107125284)

# %%
import openai
import pandas as pd

# %%
#List all txt documents in folder
import os
txt_files = [f for f in os.listdir('.') if os.path.isfile(f) and f.endswith('.txt')]
print(txt_files)
# Out:
# ['news_09.txt', 'news_08.txt', 'news_03.txt', 'news_02.txt', 'news_01.txt', 'news_05.txt', 'news_04.txt', 'news_10.txt', 'news_06.txt', 'news_07.txt']

# %%
#Read every document and merge them into a string of text
#Remove trivial words
replacelist = ["\n","\u200b","\\"]
tmp = ''
for i in txt_files:
    with open(i, 'r',) as fh:
        print(i)
        news = str(fh.read())
        for i in replacelist:
                news = news.replace(i, '')
        tmp = tmp + news
print(len(tmp))
# Out:
# news_09.txt
# news_08.txt
# news_03.txt
# news_02.txt
# news_01.txt
# news_05.txt
# news_04.txt
# news_10.txt
# news_06.txt
# news_07.txt
# 78542

# %%
keyfile = open("/Users/anderson/Desktop/Data Science/OpenAI/key.txt", "r")
key = keyfile.readline()
openai.api_key = key

# %%
#Set the lengh of every paragraph
plength = 3200
max_i = int(len(tmp)/plength) + 1
data = []
for i in range(0,max_i):
    data.append(tmp[ i*plength : (i+1)*plength ])
print(max_i,'\n',data[-1])
print(len(data))
# Out:
# 25
#  to retire — he's 80VIDEO A day in the life of a family doctorCBC INVESTIGATES Only a handful of family doctors in Ottawa accepting new patientsKingston, Ont., has a profound doctor shortage. Here's whyPhones ringing off the hook at medical clinic taking new patientsPopular Now in News1CBC INVESTIGATESTroubled Calgary builder leaves Edmonton homebuyers with mortgages to pay on unfinished homes355 reading now2Trudeau Foundation president, board resign, citing 'politicization' of China-linked donation271 reading now3Tupperware shares tank as company warns it may go out of business143 reading now4What we know about the leaked U.S. Pentagon documents on the Ukraine war — and potential impact136 reading now5Manhattan district attorney sues Republican Jim Jordan over Trump prosecution112 reading nowFooter LinksMy AccountProfileCBC GemNewslettersAbout CBC AccountsConnect with CBCFacebookTwitterYouTubeInstagramMobileRSSPodcastsContact CBCSubmit FeedbackHelp CentreAudience Relations, CBCP.O. Box 500 Station AToronto, ONCanada, M5W 1E6Toll-free (Canada only):1-866-306-4636About CBCCorporate InfoSitemapReuse & PermissionTerms of UsePrivacyJobsOur UnionsIndependent ProducersPolitical Ads RegistryAdChoicesServicesOmbudsmanCorrections and ClarificationsPublic AppearancesCommercial ServicesCBC ShopDoing Business with UsRenting FacilitiesRadio Canada InternationalCBC LiteAccessibilityIt is a priority for CBC to create products that are accessible to all in Canada including people with visual, hearing, motor and cognitive challenges.Closed Captioning and Described Video is available for many CBC shows offered on CBC Gem.About CBC AccessibilityAccessibility Feedback©2023 CBC/Radio-Canada. All rights reserved.Visitez Radio-Canada.ca
# 25

# %%
def chatgptfn(sub_list):
    result = ''
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are an assistant"},
            {"role": "user", "content": f"{sub_list} :give me a summary"}
        ]
    )
    for choice in response.choices:
        result += choice.message.content
    return result

# %%
#Input a paragraph into ChatGPT and display the returned summary
for i in range(0,10):
    data[i] = chatgptfn(data[i])
    print(i)
    print(data[i])
# Out:
# The Manitoba Indigenous Cultural Education Centre (MICEC) in Winnipeg has reopened to the public after three years of the pandemic shutdown. The centre is planning to display over 1,000 art pieces in 10 new exhibitions that explore Indigenous culture and history. The first exhibition, curated by Danielle Mason, documents MICEC's history as a non-profit organization that provides education and understanding of Indigenous culture. Despite being closed throughout the pandemic, MICEC continued to offer online services, such as language tables, to protect vulnerable populations. Mason hopes the collection will inspire up-and-coming artists and draw more attention to the centre's work.
# The National Council of Canadian Muslims has vowed to monitor the Quebec government's ban on public school prayer spaces. Earlier this month, Education Minister Bernard Drainville promised to prohibit schools from setting aside classrooms for religious purposes after reports emerged that at least two Montreal-area schools had reserved spaces for Muslim students to pray. The Council said in a statement that it would "take action" if students' rights were violated.
# The Quebec government has banned prayer spaces for students in schools, which has been criticized by Muslim organizations and mosques. The Education Minister, Bernard Drainville, said that students must pray "discreetly" and "silently" but would not ban prayer entirely. However, the National Council of Canadian Muslims has stated that it will monitor the situation and take action if the rights of students are violated. In earlier years, Drainville had presented a so-called values charter, which called for people who wear religious symbols to be prohibited from working in public institutions. Quebec schools, regardless of the Charter, have no obligation to open spaces dedicated to prayer; however, the government could face legal problems if it prevents students from praying altogether.
# The interim president of Laurentian University in Sudbury, Sheila Embleton, has announced that the number of high school student applications to the university has increased by 10.5% this year, reversing a decline of 43.5% last year. The university has faced financial difficulties and insolvency in recent years. Embleton credits the increase in applications to the university's efforts to communicate with students despite the pandemic and insolvency. Meanwhile, the Quebec government is facing criticism from a Muslim leader for prohibiting prayer rooms in public schools, and for its secularism law that appears to target Muslim women. The leader argues that the government must respect all citizens regardless of their religion or origin.
# Laurentian University in Sudbury, Ontario has reported an increase in applications from high school students this year, showing that the university is on the road to recovery after filing for insolvency in February 2021. While the numbers are still short of the 2021 figures, Laurentian's interim president, Sheila Embleton, sees the recent uptick as a positive sign that the university's rebuild has begun. Embleton also reported that Laurentian's recent open house had better numbers than in 2018 and 2019 before the insolvency and program cuts, signalling a brighter future for the university. Laurentian continues to review its real estate holdings to help pay its creditors, but Embleton says it's unlikely any of the core buildings on campus will be up for sale.
# Simon Fraser University (SFU) football alumni are seeking to reinstate their varsity football team through an injunction against the university. The 57-year-old program was eliminated by the university on April 4, but the SFU Football Alumni Society argues that there is a contract in place holding the university responsible through athletic scholarships. The injunction is being filed in British Columbia Supreme Court on behalf of seven players on the team.
# Simon Fraser University (SFU) in British Columbia, Canada has discontinued its football program, effective immediately, due to ongoing uncertainty caused by the NCAA Division II Lone Star Conference announcing it would drop SFU football beginning in 2024. Alumni have expressed shock at the decision, with an alumni committee formed to investigate places for the team to play next year and beyond. They have also questioned what will happen to the $2.5 million SFU football endowment, which provides about $125,000 to the program annually, if the team stays folded. Support for SFU football has come from the likes of SFU basketball alumnus and NBA coach Jay Triano, B.C. Lions owner Amar Doman, CFL Commissioner Randy Ambrosie and the CFL Players' Association. Over its history, SFU has produced some of Canada's top football talent.
# The University of Prince Edward Island (UPEI) has requested interest arbitration after mediated talks with its faculty association failed to resolve the ongoing strike, which has entered its fourth week. UPEI administration has appointed Michelle Flaherty to lead the arbitration process, which will continue negotiations while allowing students to return to class. However, the faculty association stated that interest arbitration wouldn't address their main issues.
# Faculty members at the University of Prince Edward Island (UPEI) in Canada have been on strike for three weeks, protesting low pay and the use of part-time workers. Talks between the university and the faculty have failed, leading to concerns that the strike could handicap the university for months to come. Some students called on the government to intervene in the dispute, while the university emphasised its intention to credit students for not paying faculty salaries during the strike, which has saved the institution $355,000 so far.
#
# Students at the University of Prince Edward Island (UPEI) in Canada are growing increasingly frustrated as a faculty strike enters its fourth week, with many feeling caught in the middle. The ongoing dispute, which centres on issues including workload and wages, has resulted in the cancellation of classes and anxiety for students, who are demanding arbitration to speed up a resolution. In response, university management has requested a third-party arbitrator to help bring an end to the strike. The institution has maintained that students' credits will be protected and does not anticipate a delay to the current academic year.

# %%
#Input a paragraph into ChatGPT and display the returned summary
for i in range(10,20):
    data[i] = chatgptfn(data[i])
    print(i)
    print(data[i])
# Out:
# The article discusses the use of ChatGPT, an artificial intelligence tool, in Canadian schools and the divided opinions of educators on its impact on education. Some argue that it should be banned, while others suggest incorporating it into learning while focusing on critical thinking and creativity. The article also includes comments from teachers and readers.
# ChatGPT, an artificial intelligence chatbot, has become a popular tool among students for completing their assignments. However, its use is causing apprehension in the education sector, with concerns about cheating and the quality of the answers provided. While some teachers have embraced ChatGPT and introduced it in their classrooms as an innovative learning tool, others are wary of its implications on students' learning and motivation. High school teacher Jamie Mitchell tried using ChatGPT to help his students solve calculus problems, but found that the tool made mistakes that his students quickly picked up on, proving that it is not a foolproof way to cheat. Despite its limitations, banning ChatGPT is not seen as the solution, as educators recognize the importance of arming students with the proper tools and knowledge to use these technologies in appropriate ways.
# Mindy Bingham, an American author, education consultant, and CEO of educational publishing company Academic Innovations, has expressed concern over the potential negative impact of artificial intelligence (AI) writing bots like ChatGPT on elementary school students' foundational knowledge and critical thinking skills. She argued that while such tools can be useful for adults, they may harm students' learning motivation and ability to problem-solve. To address this problem, a Princeton University student has developed GPTZero, an AI detector, to help educators detect AI-generated assignments.
# Princeton University student Edward Tian has created an AI-detector called GPTZero to combat cheating by students using the AI language model ChatGPT. Teachers from more than 30 countries have signed up for updates about the tool, which detects sudden changes in writing style indicative of human-written essays rather than those generated by machines. Tian is also developing a browser extension that can flag AI-produced misinformation. Though he acknowledges risks associated with AI in education, he advocates for responsible use of the technology.
# The roof of the Thunderbird School in O-Pipon-Na-Piwin Cree Nation collapsed over the Easter weekend due to heavy, wet snow. The community had already declared a state of emergency last month following the deaths of three people. The building was almost 50 years old and made of wood, making it prone to mildew, mould, and rot. Engineers are expected to assess the damage on Tuesday. The Chief of O-Pipon-Na-Piwin Cree Nation says they have been advocating for a new school as there have been concerns about the structure for years.
# The community of Tataskweyak Cree Nation in northern Manitoba is facing an uncertain future for the education of its children due to the closure of the Thunderbird School. The school had undergone extensive repairs in recent years, including the replacement of support columns, repairing of cracks in walls and a temporary shutdown due to a washout. The school was closed after mold was found in the walls and asbestos in the tiles during renovations. Disagreements with the federal government over the location for a new school have stunted progress, with the government saying putting a water line in the community's preferred location would be too expensive. The community says the new school would benefit everyone as they currently do not have running water. It is unknown how much repairs will cost or how long the community will be without a school.
# The Newfoundland and Labrador English School District has accepted responsibility for the discrimination against a profoundly deaf child, Carter Churchill, after a human rights tribunal ordered them to provide education and evaluation in American Sign Language and pay the family nearly $150,000. The district acknowledged that they missed opportunities early in Carter's education, leading to social isolation and impeding the development of his social and language skills. The Churchill family filed their complaint against the district when Carter was in kindergarten, stating that he wasn't getting the proper support to communicate and engage in the school curriculum. The human rights commission found the district failed to provide reasonable accommodation for Carter between 2016 and 2020, and recommended the creation of a classroom for deaf children.
# A tribunal in Newfoundland and Labrador has ordered the province’s English School District to pay more than $225,000 in damages to Todd and Kimberly Churchill for denying their deaf son, Carter, an appropriate education. The tribunal found that the district breached the province’s Human Rights Act by failing to provide qualified sign language interpretation throughout Carter’s education. Carter, who is now 11, was put into mainstream classrooms without adequate interpretation or support. The district has accepted the ruling and will pay the amount of money awarded to the Churchills.
# Municipalities in eastern Ontario are offering financial incentives of up to $100,000 to family doctors in an effort to lure them to their cities. The competition has become "intense," with municipalities offering creative incentives such as boat slips or temporary apartments. According to the Ontario College of Family Physicians, over two million Ontarians do not have a family doctor, and this shortage is felt more acutely in rural areas. Despite provincial programs not fully addressing the gaps in rural and remote areas, municipalities are using resources of their own to address the issue.
# A shortage of family doctors in Newfoundland and Labrador, Canada, is creating stress for patients, communities, and physicians. Some municipalities are offering incentives of up to $150,000 for doctors to work in their towns for a minimum of five years, leading to competition between neighboring communities. Experts warn that direct municipal cash incentives may not be the best solution as poorer municipalities might not have the means to offer such incentives. Instead, they suggest the province takes responsibility for ensuring equitable access to medical care by training and licensing more physicians.

# %%
#Input a paragraph into ChatGPT and display the returned summary
for i in range(20,len(data)):
    data[i] = chatgptfn(data[i])
    print(i)
    print(data[i])
# Out:
# The competition for family doctors in rural areas of Ontario is becoming increasingly competitive, with municipalities offering their own cash incentives to attract medical professionals. This is due to a shortage of doctors in rural areas, which has not been adequately addressed by provincial bonuses for doctors practising in these communities. Provincial policies also make it more difficult for rural practices to turn a profit, causing physicians to become more mobile and move to areas where they can increase their earnings. While local cash incentives can help, increasing provincial incentives would be a better solution.
# Eastern Ontario communities are offering cash incentives to family doctors in an effort to lure them to their areas due to a lack of available physicians. Quinte West, located near Belleville, currently offers doctors a financial incentive of $100,000 in exchange for a five-year commitment to the city. The practice of offering doctors incentives appears to be growing in other communities in eastern Ontario. The Ontario College of Family Physicians estimates that over two million Ontarians are without a family doctor, with shortages felt more acutely in rural and remote areas. Researchers say addressing access to health care should be a provincial responsibility.
# To address the shortage of doctors in rural and remote areas, many municipalities in Canada are offering their own incentives to attract and retain physicians. For example, Hastings County has increased its physician incentive program from $100,000 to $150,000 for a minimum four-year commitment, and added another $75,000 incentive to help cover relocation costs for licensed doctors returning from elsewhere in Canada or overseas. However, this approach may exacerbate the inequality in healthcare access between poorer and richer municipalities. Professor Arthur Sweetman of McMaster University believes that the responsibility of ensuring equitable access to medical care should fall on the province rather than local governments.
# Some Canadian municipalities are offering cash incentives to attract doctors to their underserved communities, but critics say this approach creates inequities in the publicly funded healthcare system. Provinces are urged to address the issue by training and licensing more physicians, rather than making access dependent on the tax base of a particular neighbourhood. While Ontario administers three programs to redistribute doctors to underserved areas, local incentives remain paltry and dated. Provincial policies that make it harder for rural practices to turn profits are driving up competitiveness, and family doctors often become more mobile, going where the opportunities are. Increasing provincial incentives is an option, but it is also important to level the playing field for rural areas which face stiff competition from large communities and big cities.
# The article discusses the shortage of family doctors in Ottawa and Kingston, with only a handful of doctors accepting new patients. The author notes the challenges this shortage creates for patients seeking medical care. The article also includes news about a troubled builder in Calgary, Tupperware's financial struggles, and the Manhattan district attorney suing Republican Jim Jordan over a Trump prosecution. The article is from CBC and includes various links for more information on CBC's corporate information and accessibility measures.

# %%
#print(data[19])

# %%
import gensim
from gensim import corpora
from pprint import pprint

# %%
# 創建詞袋
texts = [[word for word in document.lower().split()] for document in data]
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
# 訓練 LDA 模型
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus, id2word=dictionary, 
                                            num_topics=3, random_state=100, update_every=1, 
                                            chunksize=100, passes=10, alpha='auto', per_word_topics=True)

# %%
#!pip install pyLDAvis

# %%
# 輸出主題模型分析結果
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary)
pyLDAvis.display(vis)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pyLDAvis/_prepare.py:243: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   default_term_info = default_term_info.sort_values(
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el23601401652449354085672151260" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el23601401652449354085672151260_data = {"mdsDat": {"x": [-0.06372730240007925, 0.09629496545629625, -0.03256766305621699], "y": [0.051168093436500466, 0.012372705382457548, -0.06354079881895804], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [59.81404118129954, 34.223569700899475, 5.962389117800989]}, "tinfo": {"Term": ["to", "has", "doctors", "incentives", "faculty", "students", "rural", "while", "football", "students'", "school", "municipalities", "offering", "which", "arbitration", "family", "its", "address", "an", "that", "university", "education", "provincial", "sfu", "shortage", "after", "their", "of", "edward", "learning", "students", "government", "school", "pay", "rights", "language", "had", "use", "community", "recent", "public", "quebec", "found", "prayer", "muslim", "canadian", "three", "education", "carter", "deaf", "says", "cree", "human", "nation", "strike", "provide", "sign", "tribunal", "who", "he", "that", "after", "the", "district", "it", "as", "and", "will", "has", "of", "in", "for", "to", "a", "its", "university", "on", "have", "is", "an", "from", "while", "with", "by", "are", "be", "not", "doctors", "football", "incentives", "municipalities", "offering", "sfu", "shortage", "rural", "alumni", "access", "physicians.", "provincial", "cash", "medical", "team", "incentive", "eastern", "$100,000", "million", "areas,", "remote", "care", "own", "competition", "areas", "communities", "injunction", "through", "simon", "fraser", "attract", "local", "family", "ontario", "to", "more", "their", "in", "are", "of", "the", "a", "for", "and", "is", "not", "this", "has", "on", "with", "university", "association", "interest", "administration", "week.", "allowing", "resolve", "negotiations", "process,", "main", "flaherty", "class.", "return", "continue", "issues.", "michelle", "lead", "appointed", "wouldn't", "mediated", "upei", "entered", "developed", "motivation", "publishing", "detect", "she", "problem-solve.", "concern", "(ai)", "bots", "arbitration", "has", "address", "students'", "to", "faculty", "the", "while", "which", "of", "and", "its", "an", "university", "that", "for", "a", "students", "their", "with", "will", "on", "this", "school", "student", "however,", "edward", "after"], "Freq": [67.0, 21.0, 12.0, 10.0, 4.0, 12.0, 7.0, 6.0, 6.0, 3.0, 11.0, 6.0, 6.0, 7.0, 2.0, 9.0, 11.0, 3.0, 11.0, 22.0, 14.0, 6.0, 5.0, 4.0, 4.0, 4.0, 11.0, 45.0, 3.0, 3.0, 12.29337962876041, 5.87922248852279, 10.705459251254071, 4.280253647941284, 4.281551142049504, 4.278507959841773, 4.279096386308865, 4.276029144607736, 3.4802998956757554, 3.475512056489658, 3.4756588193993827, 3.4749628126260985, 3.47424205894532, 3.473114699826124, 3.4718976331672606, 3.45983832766235, 3.458936784074042, 5.8846929299072785, 2.677995702758818, 2.677437694365521, 2.6769338198323682, 2.6771311076782274, 2.6764844228664084, 2.6767599040658094, 2.676979189162775, 2.67585389228587, 2.6749145409222232, 2.6747267050201984, 2.6745517581324942, 2.6746218743703953, 18.557472209365216, 4.282742774386777, 94.98052272765334, 5.938648749800451, 8.75503173707162, 7.494275787854605, 32.96153345110177, 5.887831662674503, 15.553104151210425, 29.742230252387703, 32.145091728010954, 20.57473149689307, 37.78136213962016, 20.96689436513091, 8.289798812557464, 9.91002834004022, 9.62930148366441, 7.515904585004836, 9.183120240850565, 7.180332394894243, 6.377757188969535, 4.947020231485276, 5.92131422851462, 5.526442605027276, 6.112413285257971, 5.115261050965784, 5.107918780994972, 11.575608072124266, 6.043537499688166, 9.36738383212525, 5.970598005128768, 5.9700804024863015, 4.59007388128462, 4.56744921806075, 6.57635042284597, 3.144930646695711, 3.7887628469638415, 3.134207304412875, 5.0877291562624745, 3.771702018831411, 3.116832807505849, 2.416623217292022, 2.4148338303452874, 2.4154387489350397, 2.4149142632787104, 2.4147144592191565, 3.0506937306426893, 2.41330816115826, 2.4120389334019987, 2.4065862098200554, 3.034325727019913, 3.027836224892725, 2.331556245 ...

# %% [markdown]
# #### TOPIC 1
# ![image.png](attachment:image.png)

# %% [markdown]
# #### TOPIC 2
# ![image.png](attachment:image.png)

# %% [markdown]
# #### TOPIC 3
# ![image.png](attachment:image.png)
